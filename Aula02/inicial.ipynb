# %% [markdown]
# # Python Insights - Analisando Dados com Python
#
# ### Case - Cancelamento de Clientes
#
# Você foi contratado por uma empresa com mais de 800 mil clientes para um projeto de Dados. Recentemente a empresa percebeu que da sua base total de clientes, a maioria são clientes inativos, ou seja, que já cancelaram o serviço.
#
# Precisando melhorar seus resultados ela quer conseguir entender os principais motivos desses cancelamentos e quais as ações mais eficientes para reduzir esse número.
#
# Base de dados e arquivos: https://drive.google.com/drive/folders/1uDesZePdkhiraJmiyeZ-w5tfc8XsNYFZ?usp=drive_link

# %%
# Passo a passo do projeto 
# Passo 1: Abrir/Importar a base de dados
# Passo 2: Visualizar a base de dados
    # Entender as informações disponíveis
    # Possíveis problemas/erros na base de dados
# Passo 3: Corrigir os problemas da base de dados (Tratamento de Dados)
# Passo 4: Análise Inicial (Entender quantos clientes cancelaram)
# Passo 5: Análise Detalhada (Possíveis causas, como cada coluna impacta no cancelamento, etc)
# Out:
# A execução de células com 'Python 3.13.2' requer o pacote ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crie um ambiente Python</a> com os pacotes necessários.
#
# Ou instale 'ipykernel' usando o comando: 'c:/python313/python.exe -m pip install ipykernel -U --user --force-reinstall'
